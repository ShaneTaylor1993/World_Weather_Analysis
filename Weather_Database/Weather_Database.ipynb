# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
import requests
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 734

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description
                          })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
print(f"{len(city_data)} city records were retrived")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | anadyr
# Processing Record 2 of Set 1 | mahebourg
# Processing Record 3 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 4 of Set 1 | zatoka
# Processing Record 5 of Set 1 | butaritari
# Processing Record 6 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 7 of Set 1 | bluff
# Processing Record 8 of Set 1 | saskylakh
# Processing Record 9 of Set 1 | provideniya
# Processing Record 10 of Set 1 | zhigansk
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | asau
# Processing Record 13 of Set 1 | muros
# Processing Record 14 of Set 1 | nikolskoye
# Processing Record 15 of Set 1 | hithadhoo
# Processing Record 16 of Set 1 | hisua
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | kikwit
# Processing Record 19 of Set 1 | manfredonia
# Processing Record 20 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | cidreira
# Processing Record 23 of Set 1 | srednekolymsk
# Processing Record 24 of Set 1 | kapaa
# Processing Record 25 of Set 1 | luderitz
# Processing Record 26 of Set 1 | mattru
# Processing Record 27 of Set 1 | mataura
# Processing Record 28 of Set 1 | ostersund
# Processing Record 29 of Set 1 | walvis bay
# Processing Record 30 of Set 1 | ponta do sol
# Processing Record 31 of Set 1 | albany
# Processing Record 32 of Set 1 | ocos
# Processing Record 33 of Set 1 | lebu
# Processing Record 34 of Set 1 | aklavik
# Processing Record 35 of Set 1 | baghdad
# Processing Record 36 of Set 1 | jamestown
# Processing Record 37 of Set 1 | kieta
# Processing Record 38 of Set 1 | chuy
# Processing Record 39 of Set 1 | adrar
# Processing Record 40 of Set 1 | shimoda
# Processing Record 41 of Set 1 | lakes entrance
# Processing Record 42 of Set 1 | hovd
# Processing Record 43 of Set 1 | iqaluit
# Processing Record 44 of Set 1 | punta arenas
# Processing Record 45 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 1 | vanimo
# Processing Record 47 of Set 1 | cordoba
# Processing Record 48 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 49 of Set 1 | comodoro rivadavia
# Processing Record 50 of Set 1 | hermanus
# Processing Record 1 of Set 2 | jinchang
# Processing Record 2 of Set 2 | ampanihy
# Processing Record 3 of Set 2 | lang son
# Processing Record 4 of Set 2 | krusa
# Processing Record 5 of Set 2 | vestmannaeyjar
# Processing Record 6 of Set 2 | broome
# Processing Record 7 of Set 2 | hilo
# Processing Record 8 of Set 2 | new norfolk
# Processing Record 9 of Set 2 | arraial do cabo
# Processing Record 10 of Set 2 | puerto madryn
# Processing Record 11 of Set 2 | esperance
# Processing Record 12 of Set 2 | puerto escondido
# Processing Record 13 of Set 2 | tasiilaq
# Processing Record 14 of Set 2 | carnarvon
# Processing Record 15 of Set 2 | linhares
# Processing Record 16 of Set 2 | jumla
# Processing Record 17 of Set 2 | tabarqah
# City not found. Skipping...
# Processing Record 18 of Set 2 | ilulissat
# Processing Record 19 of Set 2 | husavik
# Processing Record 20 of Set 2 | warragul
# Processing Record 21 of Set 2 | port alfred
# Processing Record 22 of Set 2 | tiarei
# Processing Record 23 of Set 2 | alofi
# Processing Record 24 of Set 2 | podgornoye
# Processing Record 25 of Set 2 | morant bay
# Processing Record 26 of Set 2 | metro
# Processing Record 27 of Set 2 | mar del plata
# Processing Record 28 of Set 2 | fort nelson
# Processing Record 29 of Set 2 | parana
# Processing Record 30 of Set 2 | baglan
# Processing Record 31 of Set 2 | migori
# Processing Record 32 of Set 2 | nishihara
# Processing Record 33 of Set 2 | prince rupert
# Processing Record 34 of Set 2 | pevek
# Processing Record 35 of Set 2 | flin flon
# Processing Record 36 of Set 2 | khorixas
# Processing Record 37 of Set 2 | puerto ayora
# Processing Record 38 of Set 2 | bunbury
# Processing Record 39 of Set 2 | cabo san lucas
# Processing Record 40 of Set 2 | moussoro
# Processing Record 41 of Set 2 | san juan
# Processing Record 42 of Set 2 | hasaki
# Processing Record 43 of Set 2 | victoria
# Processing Record 44 of Set 2 | moerai
# Processing Record 45 of Set 2 | cherskiy
# Processing Record 46 of Set 2 | tobol
# Processing Record 47 of Set 2 | isangel
# Processing Record 48 of Set 2 | quthing
# Processing Record 49 of Set 2 | kavieng
# Processing Record 50 of Set 2 | deputatskiy
# Processing Record 1 of Set 3 | barrow
# Processing Record 2 of Set 3 | laurel
# Processing Record 3 of Set 3 | namibe
# Processing Record 4 of Set 3 | hobart
# Processing Record 5 of Set 3 | nashua
# Processing Record 6 of Set 3 | brae
# Processing Record 7 of Set 3 | erzincan
# Processing Record 8 of Set 3 | alghero
# Processing Record 9 of Set 3 | biltine
# Processing Record 10 of Set 3 | kahului
# Processing Record 11 of Set 3 | paita
# Processing Record 12 of Set 3 | qaanaaq
# Processing Record 13 of Set 3 | coihaique
# Processing Record 14 of Set 3 | vaini
# Processing Record 15 of Set 3 | tucuma
# Processing Record 16 of Set 3 | kodiak
# Processing Record 17 of Set 3 | naze
# Processing Record 18 of Set 3 | kaitangata
# Processing Record 19 of Set 3 | umm kaddadah
# Processing Record 20 of Set 3 | biak
# Processing Record 21 of Set 3 | fayaoue
# Processing Record 22 of Set 3 | inirida
# Processing Record 23 of Set 3 | ous
# Processing Record 24 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 3 | saint-philippe
# Processing Record 26 of Set 3 | san quintin
# Processing Record 27 of Set 3 | thompson
# Processing Record 28 of Set 3 | saint george
# Processing Record 29 of Set 3 | port-gentil
# Processing Record 30 of Set 3 | margate
# Processing Record 31 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 3 | lasa
# Processing Record 33 of Set 3 | vostok
# Processing Record 34 of Set 3 | alta floresta
# Processing Record 35 of Set 3 | mbacke
# City not found. Skipping...
# Processing Record 36 of Set 3 | juneau
# Processing Record 37 of Set 3 | san-pedro
# Processing Record 38 of Set 3 | maragogi
# Processing Record 39 of Set 3 | kuching
# Processing Record 40 of Set 3 | bongandanga
# Processing Record 41 of Set 3 | port lincoln
# Processing Record 42 of Set 3 | laguna
# Processing Record 43 of Set 3 | port elizabeth
# Processing Record 44 of Set 3 | zyryanka
# Processing Record 45 of Set 3 | norman wells
# Processing Record 46 of Set 3 | anyang
# Processing Record 47 of Set 3 | gorom-gorom
# Processing Record 48 of Set 3 | male
# Processing Record 49 of Set 3 | noumea
# Processing Record 50 of Set 3 | avarua
# Processing Record 1 of Set 4 | artyom
# Processing Record 2 of Set 4 | antalaha
# Processing Record 3 of Set 4 | norrkoping
# Processing Record 4 of Set 4 | hirara
# Processing Record 5 of Set 4 | chapais
# Processing Record 6 of Set 4 | teya
# Processing Record 7 of Set 4 | sakhon nakhon
# Processing Record 8 of Set 4 | hailin
# Processing Record 9 of Set 4 | malindi
# Processing Record 10 of Set 4 | torbay
# Processing Record 11 of Set 4 | castro
# Processing Record 12 of Set 4 | tateyama
# Processing Record 13 of Set 4 | cape town
# Processing Record 14 of Set 4 | talnakh
# Processing Record 15 of Set 4 | jalu
# Processing Record 16 of Set 4 | harper
# Processing Record 17 of Set 4 | alice town
# Processing Record 18 of Set 4 | qingdao
# Processing Record 19 of Set 4 | egvekinot
# Processing Record 20 of Set 4 | tarauaca
# Processing Record 21 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 4 | grants pass
# Processing Record 23 of Set 4 | moengo
# Processing Record 24 of Set 4 | yellowknife
# Processing Record 25 of Set 4 | santa rosalia
# Processing Record 26 of Set 4 | tuktoyaktuk
# Processing Record 27 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 4 | bengkulu
# Processing Record 29 of Set 4 | cleethorpes
# Processing Record 30 of Set 4 | saint anthony
# Processing Record 31 of Set 4 | brigantine
# Processing Record 32 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 33 of Set 4 | tiksi
# Processing Record 34 of Set 4 | hwange
# Processing Record 35 of Set 4 | padang
# Processing Record 36 of Set 4 | bethel
# Processing Record 37 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 4 | lorengau
# Processing Record 39 of Set 4 | ostrovnoy
# Processing Record 40 of Set 4 | tuatapere
# Processing Record 41 of Set 4 | keetmanshoop
# Processing Record 42 of Set 4 | ulladulla
# Processing Record 43 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 44 of Set 4 | urumqi
# Processing Record 45 of Set 4 | mucuri
# Processing Record 46 of Set 4 | shingu
# Processing Record 47 of Set 4 | ambulu
# Processing Record 48 of Set 4 | uray
# Processing Record 49 of Set 4 | pangnirtung
# Processing Record 50 of Set 4 | udachnyy
# Processing Record 1 of Set 5 | san patricio
# Processing Record 2 of Set 5 | grand forks
# Processing Record 3 of Set 5 | turukhansk
# Processing Record 4 of Set 5 | larsnes
# Processing Record 5 of Set 5 | broken hill
# Processing Record 6 of Set 5 | roald
# Processing Record 7 of Set 5 | japura
# Processing Record 8 of Set 5 | umm lajj
# Processing Record 9 of Set 5 | moanda
# Processing Record 10 of Set 5 | sao filipe
# Processing Record 11 of Set 5 | atuona
# Processing Record 12 of Set 5 | georgetown
# Processing Record 13 of Set 5 | fairbanks
# Processing Record 14 of Set 5 | mundo nuevo
# Processing Record 15 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 16 of Set 5 | kruisfontein
# Processing Record 17 of Set 5 | chumikan
# Processing Record 18 of Set 5 | bredasdorp
# Processing Record 19 of Set 5 | east london
# Processing Record 20 of Set 5 | severo-yeniseyskiy
# Processing Record 21 of Set 5 | bambous virieux
# Processing Record 22 of Set 5 | natal
# Processing Record 23 of Set 5 | anshun
# Processing Record 24 of Set 5 | fortuna
# Processing Record 25 of Set 5 | touros
# Processing Record 26 of Set 5 | jingdezhen
# Processing Record 27 of Set 5 | necochea
# Processing Record 28 of Set 5 | batemans bay
# Processing Record 29 of Set 5 | bathsheba
# Processing Record 30 of Set 5 | najran
# Processing Record 31 of Set 5 | goure
# Processing Record 32 of Set 5 | sorong
# Processing Record 33 of Set 5 | kalmunai
# Processing Record 34 of Set 5 | khilok
# Processing Record 35 of Set 5 | kabalo
# Processing Record 36 of Set 5 | salalah
# Processing Record 37 of Set 5 | nanortalik
# Processing Record 38 of Set 5 | tazovskiy
# Processing Record 39 of Set 5 | hervey bay
# Processing Record 40 of Set 5 | airai
# Processing Record 41 of Set 5 | dhangadhi
# Processing Record 42 of Set 5 | lerwick
# Processing Record 43 of Set 5 | ikalamavony
# Processing Record 44 of Set 5 | balkanabat
# Processing Record 45 of Set 5 | upernavik
# Processing Record 46 of Set 5 | nouakchott
# Processing Record 47 of Set 5 | rigaud
# Processing Record 48 of Set 5 | lompoc
# Processing Record 49 of Set 5 | ponta delgada
# Processing Record 50 of Set 5 | coromandel
# Processing Record 1 of Set 6 | mae sai
# Processing Record 2 of Set 6 | sokolo
# Processing Record 3 of Set 6 | lagoa
# Processing Record 4 of Set 6 | buala
# Processing Record 5 of Set 6 | yulara
# Processing Record 6 of Set 6 | sergeyevka
# Processing Record 7 of Set 6 | maneadero
# Processing Record 8 of Set 6 | bacolod
# Processing Record 9 of Set 6 | griffith
# Processing Record 10 of Set 6 | longlac
# City not found. Skipping...
# Processing Record 11 of Set 6 | ukiah
# Processing Record 12 of Set 6 | kiunga
# Processing Record 13 of Set 6 | clarence town
# Processing Record 14 of Set 6 | pergamino
# Processing Record 15 of Set 6 | khatanga
# Processing Record 16 of Set 6 | tommot
# Processing Record 17 of Set 6 | taoudenni
# Processing Record 18 of Set 6 | usinsk
# Processing Record 19 of Set 6 | angul
# Processing Record 20 of Set 6 | kununurra
# Processing Record 21 of Set 6 | caiaponia
# Processing Record 22 of Set 6 | longyearbyen
# Processing Record 23 of Set 6 | vanavara
# Processing Record 24 of Set 6 | port hardy
# Processing Record 25 of Set 6 | acapulco
# Processing Record 26 of Set 6 | mayskiy
# Processing Record 27 of Set 6 | portland
# Processing Record 28 of Set 6 | makokou
# Processing Record 29 of Set 6 | smithers
# Processing Record 30 of Set 6 | roma
# Processing Record 31 of Set 6 | flagstaff
# Processing Record 32 of Set 6 | honolulu
# Processing Record 33 of Set 6 | constitucion
# Processing Record 34 of Set 6 | saldanha
# Processing Record 35 of Set 6 | tura
# Processing Record 36 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 6 | bemidji
# Processing Record 38 of Set 6 | maniitsoq
# Processing Record 39 of Set 6 | mahanoro
# Processing Record 40 of Set 6 | north platte
# Processing Record 41 of Set 6 | dikson
# Processing Record 42 of Set 6 | george
# Processing Record 43 of Set 6 | haines junction
# Processing Record 44 of Set 6 | khipro
# Processing Record 45 of Set 6 | saint-francois
# Processing Record 46 of Set 6 | vila velha
# Processing Record 47 of Set 6 | chicama
# Processing Record 48 of Set 6 | poum
# Processing Record 49 of Set 6 | bastia
# Processing Record 50 of Set 6 | acara
# Processing Record 1 of Set 7 | vardo
# Processing Record 2 of Set 7 | barcelona
# Processing Record 3 of Set 7 | khandyga
# Processing Record 4 of Set 7 | hami
# Processing Record 5 of Set 7 | cururupu
# Processing Record 6 of Set 7 | kamenka
# Processing Record 7 of Set 7 | barabinsk
# Processing Record 8 of Set 7 | marsabit
# Processing Record 9 of Set 7 | chokurdakh
# Processing Record 10 of Set 7 | kazachinskoye
# Processing Record 11 of Set 7 | ribeira grande
# Processing Record 12 of Set 7 | leh
# Processing Record 13 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 14 of Set 7 | cortes
# Processing Record 15 of Set 7 | santiago
# Processing Record 16 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 17 of Set 7 | at-bashi
# Processing Record 18 of Set 7 | santa maria da vitoria
# Processing Record 19 of Set 7 | itarema
# Processing Record 20 of Set 7 | rabo de peixe
# Processing Record 21 of Set 7 | turayf
# Processing Record 22 of Set 7 | cairns
# Processing Record 23 of Set 7 | chunoyar
# Processing Record 24 of Set 7 | buchanan
# Processing Record 25 of Set 7 | alberdi
# Processing Record 26 of Set 7 | benghazi
# Processing Record 27 of Set 7 | culebra
# Processing Record 28 of Set 7 | coihueco
# Processing Record 29 of Set 7 | izumo
# Processing Record 30 of Set 7 | tahta
# Processing Record 31 of Set 7 | katesh
# Processing Record 32 of Set 7 | klaksvik
# Processing Record 33 of Set 7 | baoqing
# Processing Record 34 of Set 7 | tromso
# Processing Record 35 of Set 7 | katsuura
# Processing Record 36 of Set 7 | letlhakeng
# Processing Record 37 of Set 7 | polyarnyy
# Processing Record 38 of Set 7 | karratha
# Processing Record 39 of Set 7 | sitka
# Processing Record 40 of Set 7 | san jose
# Processing Record 41 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 7 | vestmanna
# Processing Record 43 of Set 7 | paradwip
# City not found. Skipping...
# Processing Record 44 of Set 7 | mendi
# Processing Record 45 of Set 7 | ellensburg
# Processing Record 46 of Set 7 | kollo
# Processing Record 47 of Set 7 | maceio
# Processing Record 48 of Set 7 | morrope
# Processing Record 49 of Set 7 | stykkisholmur
# Processing Record 50 of Set 7 | acajutla
# Processing Record 1 of Set 8 | celendin
# Processing Record 2 of Set 8 | dossor
# Processing Record 3 of Set 8 | grand centre
# City not found. Skipping...
# Processing Record 4 of Set 8 | swindon
# Processing Record 5 of Set 8 | atar
# Processing Record 6 of Set 8 | talcahuano
# Processing Record 7 of Set 8 | ghanzi
# Processing Record 8 of Set 8 | awbari
# Processing Record 9 of Set 8 | imeni poliny osipenko
# Processing Record 10 of Set 8 | iglino
# Processing Record 11 of Set 8 | west wendover
# Processing Record 12 of Set 8 | burnie
# Processing Record 13 of Set 8 | menomonie
# Processing Record 14 of Set 8 | aginskoye
# Processing Record 15 of Set 8 | sunrise manor
# Processing Record 16 of Set 8 | port blair
# Processing Record 17 of Set 8 | porto murtinho
# Processing Record 18 of Set 8 | severnyy
# Processing Record 19 of Set 8 | tygda
# Processing Record 20 of Set 8 | surgut
# Processing Record 21 of Set 8 | englehart
# Processing Record 22 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 23 of Set 8 | cervo
# Processing Record 24 of Set 8 | teeli
# Processing Record 25 of Set 8 | hamilton
# Processing Record 26 of Set 8 | college
# Processing Record 27 of Set 8 | bako
# Processing Record 28 of Set 8 | kawalu
# Processing Record 29 of Set 8 | bajo baudo
# City not found. Skipping...
# Processing Record 30 of Set 8 | oswego
# Processing Record 31 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 32 of Set 8 | funadhoo
# Processing Record 33 of Set 8 | sola
# Processing Record 34 of Set 8 | pemangkat
# Processing Record 35 of Set 8 | jamame
# Processing Record 36 of Set 8 | san cristobal
# Processing Record 37 of Set 8 | chopinzinho
# Processing Record 38 of Set 8 | fukue
# Processing Record 39 of Set 8 | camacupa
# Processing Record 40 of Set 8 | nicoya
# Processing Record 41 of Set 8 | dongsheng
# Processing Record 42 of Set 8 | tougue
# Processing Record 43 of Set 8 | santo angelo
# Processing Record 44 of Set 8 | tchollire
# Processing Record 45 of Set 8 | ancud
# Processing Record 46 of Set 8 | awang
# Processing Record 47 of Set 8 | tual
# Processing Record 48 of Set 8 | kampong chhnang
# Processing Record 49 of Set 8 | pallasovka
# Processing Record 50 of Set 8 | gat
# Processing Record 1 of Set 9 | ust-kulom
# Processing Record 2 of Set 9 | kavaratti
# Processing Record 3 of Set 9 | bobo dioulasso
# Processing Record 4 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 5 of Set 9 | maturin
# Processing Record 6 of Set 9 | ayagoz
# Processing Record 7 of Set 9 | shelburne
# Processing Record 8 of Set 9 | alenquer
# Processing Record 9 of Set 9 | morgan city
# Processing Record 10 of Set 9 | sao joao da barra
# Processing Record 11 of Set 9 | paamiut
# Processing Record 12 of Set 9 | lagos
# Processing Record 13 of Set 9 | sao jose da coroa grande
# Processing Record 14 of Set 9 | chatham
# Processing Record 15 of Set 9 | lata
# Processing Record 16 of Set 9 | shaunavon
# Processing Record 17 of Set 9 | groton
# Processing Record 18 of Set 9 | souillac
# Processing Record 19 of Set 9 | am timan
# Processing Record 20 of Set 9 | coquimbo
# Processing Record 21 of Set 9 | mamallapuram
# Processing Record 22 of Set 9 | faanui
# Processing Record 23 of Set 9 | waipawa
# Processing Record 24 of Set 9 | nizwa
# Processing Record 25 of Set 9 | dajal
# Processing Record 26 of Set 9 | amga
# Processing Record 27 of Set 9 | ixtapa
# Processing Record 28 of Set 9 | yellamanchili
# City not found. Skipping...
# Processing Record 29 of Set 9 | estrela
# Processing Record 30 of Set 9 | tias
# Processing Record 31 of Set 9 | vanderhoof
# Processing Record 32 of Set 9 | celestun
# Processing Record 33 of Set 9 | joshimath
# Processing Record 34 of Set 9 | nemuro
# Processing Record 35 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 9 | muisne
# Processing Record 37 of Set 9 | flinders
# Processing Record 38 of Set 9 | manacor
# Processing Record 39 of Set 9 | aguimes
# Processing Record 40 of Set 9 | neiafu
# Processing Record 41 of Set 9 | sioux lookout
# Processing Record 42 of Set 9 | korla
# Processing Record 43 of Set 9 | bocas del toro
# Processing Record 44 of Set 9 | nome
# Processing Record 45 of Set 9 | yerbogachen
# Processing Record 46 of Set 9 | pierre
# Processing Record 47 of Set 9 | abatskoye
# Processing Record 48 of Set 9 | opuwo
# Processing Record 49 of Set 9 | linxia
# Processing Record 50 of Set 9 | balikpapan
# Processing Record 1 of Set 10 | sulangan
# Processing Record 2 of Set 10 | mangochi
# Processing Record 3 of Set 10 | hofn
# Processing Record 4 of Set 10 | windhoek
# Processing Record 5 of Set 10 | kholmogory
# Processing Record 6 of Set 10 | kichmengskiy gorodok
# Processing Record 7 of Set 10 | rocha
# Processing Record 8 of Set 10 | jining
# Processing Record 9 of Set 10 | florence
# Processing Record 10 of Set 10 | honiara
# Processing Record 11 of Set 10 | los llanos de aridane
# Processing Record 12 of Set 10 | ahipara
# Processing Record 13 of Set 10 | sinegorye
# Processing Record 14 of Set 10 | boralday
# Processing Record 15 of Set 10 | tilichiki
# Processing Record 16 of Set 10 | clyde river
# Processing Record 17 of Set 10 | imbituba
# Processing Record 18 of Set 10 | kidal
# Processing Record 19 of Set 10 | hokitika
# Processing Record 20 of Set 10 | visnes
# Processing Record 21 of Set 10 | kungurtug
# Processing Record 22 of Set 10 | taos
# Processing Record 23 of Set 10 | rameswaram
# Processing Record 24 of Set 10 | berlevag
# Processing Record 25 of Set 10 | svetlogorsk
# Processing Record 26 of Set 10 | itoman
# Processing Record 27 of Set 10 | agnibilekrou
# Processing Record 28 of Set 10 | awjilah
# Processing Record 29 of Set 10 | verkh-usugli
# Processing Record 30 of Set 10 | camacha
# Processing Record 31 of Set 10 | homer
# Processing Record 32 of Set 10 | erzin
# Processing Record 33 of Set 10 | abu samrah
# Processing Record 34 of Set 10 | mana
# Processing Record 35 of Set 10 | mercedes
# Processing Record 36 of Set 10 | calama
# Processing Record 37 of Set 10 | lumberton
# Processing Record 38 of Set 10 | tutoia
# Processing Record 39 of Set 10 | aripuana
# Processing Record 40 of Set 10 | ballina
# Processing Record 41 of Set 10 | sadove
# Processing Record 42 of Set 10 | pangai
# Processing Record 43 of Set 10 | bull savanna
# Processing Record 44 of Set 10 | changli
# Processing Record 45 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 46 of Set 10 | altamont
# Processing Record 47 of Set 10 | kikerino
# Processing Record 48 of Set 10 | copiapo
# Processing Record 49 of Set 10 | nevsehir
# Processing Record 50 of Set 10 | praia da vitoria
# Processing Record 1 of Set 11 | mutoko
# Processing Record 2 of Set 11 | colac
# Processing Record 3 of Set 11 | sabha
# Processing Record 4 of Set 11 | panguna
# Processing Record 5 of Set 11 | mount isa
# Processing Record 6 of Set 11 | sarangani
# Processing Record 7 of Set 11 | jalingo
# Processing Record 8 of Set 11 | axim
# Processing Record 9 of Set 11 | high level
# Processing Record 10 of Set 11 | meulaboh
# Processing Record 11 of Set 11 | moron
# Processing Record 12 of Set 11 | ibotirama
# Processing Record 13 of Set 11 | lavrentiya
# Processing Record 14 of Set 11 | olafsvik
# Processing Record 15 of Set 11 | alakurtti
# Processing Record 16 of Set 11 | whitehorse
# Processing Record 17 of Set 11 | dali
# Processing Record 18 of Set 11 | abu kamal
# Processing Record 19 of Set 11 | dunedin
# Processing Record 20 of Set 11 | maningrida
# Processing Record 21 of Set 11 | honiton
# Processing Record 22 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 23 of Set 11 | bluefields
# Processing Record 24 of Set 11 | san pedro
# Processing Record 25 of Set 11 | tehri
# Processing Record 26 of Set 11 | shakiso
# Processing Record 27 of Set 11 | phangnga
# Processing Record 28 of Set 11 | guerrero negro
# Processing Record 29 of Set 11 | pisco
# Processing Record 30 of Set 11 | chaa-khol
# City not found. Skipping...
# Processing Record 31 of Set 11 | west lafayette
# Processing Record 32 of Set 11 | beroroha
# Processing Record 33 of Set 11 | matara
# Processing Record 34 of Set 11 | evanston
# Processing Record 35 of Set 11 | coos bay
# Processing Record 36 of Set 11 | jiuquan
# Processing Record 37 of Set 11 | tigil
# Processing Record 38 of Set 11 | ketchikan
# Processing Record 39 of Set 11 | cayenne
# Processing Record 40 of Set 11 | bandarbeyla
# Processing Record 41 of Set 11 | nouadhibou
# Processing Record 42 of Set 11 | geraldton
# Processing Record 43 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 11 | santa isabel do rio negro
# Processing Record 45 of Set 11 | kingston
# Processing Record 46 of Set 11 | severo-kurilsk
# Processing Record 47 of Set 11 | ouadda
# Processing Record 48 of Set 11 | codrington
# Processing Record 49 of Set 11 | barabai
# Processing Record 50 of Set 11 | bang saphan
# Processing Record 1 of Set 12 | grindavik
# Processing Record 2 of Set 12 | ambodifototra
# City not found. Skipping...
# Processing Record 3 of Set 12 | inhambane
# Processing Record 4 of Set 12 | havoysund
# Processing Record 5 of Set 12 | fort-shevchenko
# Processing Record 6 of Set 12 | ambilobe
# Processing Record 7 of Set 12 | wajir
# Processing Record 8 of Set 12 | satitoa
# City not found. Skipping...
# Processing Record 9 of Set 12 | senno
# Processing Record 10 of Set 12 | aksarka
# Processing Record 11 of Set 12 | san vicente
# Processing Record 12 of Set 12 | meadow lake
# Processing Record 13 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 14 of Set 12 | wladyslawowo
# Processing Record 15 of Set 12 | ozgon
# City not found. Skipping...
# Processing Record 16 of Set 12 | alice springs
# Processing Record 17 of Set 12 | cap malheureux
# Processing Record 18 of Set 12 | gunjur
# Processing Record 19 of Set 12 | belyy yar
# Processing Record 20 of Set 12 | grand island
# Processing Record 21 of Set 12 | tabou
# Processing Record 22 of Set 12 | chara
# Processing Record 23 of Set 12 | paciran
# Processing Record 24 of Set 12 | batman
# Processing Record 25 of Set 12 | puno
# Processing Record 26 of Set 12 | mullaitivu
# City not found. Skipping...
# Processing Record 27 of Set 12 | montepuez
# Processing Record 28 of Set 12 | port moresby
# Processing Record 29 of Set 12 | leningradskiy
# Processing Record 30 of Set 12 | shebalino
# Processing Record 31 of Set 12 | ahuimanu
# Processing Record 32 of Set 12 | nohar
# Processing Record 33 of Set 12 | rochegda
# Processing Record 34 of Set 12 | lubango
# Processing Record 35 of Set 12 | tocopilla
# Processing Record 36 of Set 12 | sotouboua
# Processing Record 37 of Set 12 | mount gambier
# Processing Record 38 of Set 12 | erenhot
# Processing Record 39 of Set 12 | kyabram
# Processing Record 40 of Set 12 | kusu
# Processing Record 41 of Set 12 | diffa
# Processing Record 42 of Set 12 | dukat
# Processing Record 43 of Set 12 | henties bay
# Processing Record 44 of Set 12 | innisfail
# Processing Record 45 of Set 12 | shizunai
# Processing Record 46 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 47 of Set 12 | vao
# Processing Record 48 of Set 12 | hvide sande
# Processing Record 49 of Set 12 | touho
# Processing Record 50 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 1 of Set 13 | nara
# Processing Record 2 of Set 13 | voznesenskaya
# Processing Record 3 of Set 13 | sibu
# Processing Record 4 of Set 13 | fare
# Processing Record 5 of Set 13 | kadykchan
# City not found. Skipping...
# Processing Record 6 of Set 13 | grand gaube
# Processing Record 7 of Set 13 | marawi
# Processing Record 8 of Set 13 | huangcun
# Processing Record 9 of Set 13 | dangriga
# Processing Record 10 of Set 13 | kargasok
# Processing Record 11 of Set 13 | asfi
# Processing Record 12 of Set 13 | makakilo city
# Processing Record 13 of Set 13 | saint-georges
# Processing Record 14 of Set 13 | lunenburg
# Processing Record 15 of Set 13 | liwale
# Processing Record 16 of Set 13 | onega
# Processing Record 17 of Set 13 | north bend
# Processing Record 18 of Set 13 | makurdi
# Processing Record 19 of Set 13 | okhotsk
# Processing Record 20 of Set 13 | phuthaditjhaba
# Processing Record 21 of Set 13 | golyshmanovo
# Processing Record 22 of Set 13 | jiazi
# Processing Record 23 of Set 13 | merauke
# Processing Record 24 of Set 13 | astipalaia
# City not found. Skipping...
# Processing Record 25 of Set 13 | deh rawud
# City not found. Skipping...
# Processing Record 26 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 27 of Set 13 | ushtobe
# Processing Record 28 of Set 13 | micheweni
# Processing Record 29 of Set 13 | sinnamary
# Processing Record 30 of Set 13 | lavello
# Processing Record 31 of Set 13 | manzanillo
# Processing Record 32 of Set 13 | kamaishi
# Processing Record 33 of Set 13 | pechora
# Processing Record 34 of Set 13 | la ronge
# Processing Record 35 of Set 13 | presidencia roque saenz pena
# Processing Record 36 of Set 13 | rincon
# Processing Record 37 of Set 13 | skjervoy
# Processing Record 38 of Set 13 | waingapu
# Processing Record 39 of Set 13 | gulshat
# City not found. Skipping...
# Processing Record 40 of Set 13 | plunge
# Processing Record 41 of Set 13 | nakasongola
# Processing Record 42 of Set 13 | vaitape
# Processing Record 43 of Set 13 | sukumo
# Processing Record 44 of Set 13 | gorontalo
# Processing Record 45 of Set 13 | shache
# Processing Record 46 of Set 13 | shaghat
# Processing Record 47 of Set 13 | hailar
# Processing Record 48 of Set 13 | bethlehem
# Processing Record 49 of Set 13 | vylgort
# City not found. Skipping...
# Processing Record 50 of Set 13 | farap
# Processing Record 1 of Set 14 | westport
# Processing Record 2 of Set 14 | cary
# Processing Record 3 of Set 14 | richards bay
# Processing Record 4 of Set 14 | san francisco del mar
# Processing Record 5 of Set 14 | galle
# Processing Record 6 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 7 of Set 14 | forbes
# Processing Record 8 of Set 14 | parfino
# Processing Record 9 of Set 14 | kariapatti
# Processing Record 10 of Set 14 | monze
# Processing Record 11 of Set 14 | hambantota
# Processing Record 12 of Set 14 | shepsi
# Processing Record 13 of Set 14 | bonavista
# Processing Record 14 of Set 14 | banda aceh
# Processing Record 15 of Set 14 | kurumkan
# Processing Record 16 of Set 14 | carlos chagas
# Processing Record 17 of Set 14 | ouango
# Processing Record 18 of Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 19 of Set 14 | norsup
# Processing Record 20 of Set 14 | mildura
# Processing Record 21 of Set 14 | hobyo
# Processing Record 22 of Set 14 | takapau
# Processing Record 23 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 24 of Set 14 | kyshtovka
# Processing Record 25 of Set 14 | emba
# Processing Record 26 of Set 14 | mogok
# Processing Record 27 of Set 14 | kharan
# Processing Record 28 of Set 14 | bondo
# Processing Record 29 of Set 14 | ariano irpino
# Processing Record 30 of Set 14 | pyay
# Processing Record 31 of Set 14 | bud
# Processing Record 32 of Set 14 | general roca
# Processing Record 33 of Set 14 | lincoln
# Processing Record 34 of Set 14 | shahpur
# Processing Record 35 of Set 14 | nabul
# City not found. Skipping...
# Processing Record 36 of Set 14 | porto novo
# Processing Record 37 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 38 of Set 14 | aykhal
# Processing Record 39 of Set 14 | khasan
# Processing Record 40 of Set 14 | olinda
# Processing Record 41 of Set 14 | kulhudhuffushi
# Processing Record 42 of Set 14 | okha
# Processing Record 43 of Set 14 | tepalcatepec
# Processing Record 44 of Set 14 | saint-leu
# Processing Record 45 of Set 14 | millau
# Processing Record 46 of Set 14 | madinat sittah uktubar
# Processing Record 47 of Set 14 | lauria
# Processing Record 48 of Set 14 | dawson creek
# Processing Record 49 of Set 14 | riyadh
# Processing Record 50 of Set 14 | aksum
# Processing Record 1 of Set 15 | bronnoysund
# Processing Record 2 of Set 15 | reconquista
# Processing Record 3 of Set 15 | araouane
# Processing Record 4 of Set 15 | tezu
# Processing Record 5 of Set 15 | llanes
# Processing Record 6 of Set 15 | buin
# Processing Record 7 of Set 15 | sangar
# Processing Record 8 of Set 15 | khani
# Processing Record 9 of Set 15 | kaoma
# Processing Record 10 of Set 15 | bafra
# Processing Record 11 of Set 15 | jubayl
# City not found. Skipping...
# Processing Record 12 of Set 15 | iracoubo
# Processing Record 13 of Set 15 | port-cartier
# Processing Record 14 of Set 15 | samarai
# Processing Record 15 of Set 15 | altamira
# Processing Record 16 of Set 15 | novoselytsya
# Processing Record 17 of Set 15 | antofagasta
# Processing Record 18 of Set 15 | tres arroyos
# Processing Record 19 of Set 15 | jinka
# Processing Record 20 of Set 15 | mae hong son
# Processing Record 21 of Set 15 | bowen
# Processing Record 22 of Set 15 | kungur
# Processing Record 23 of Set 15 | surt
# Processing Record 24 of Set 15 | tiznit
# Processing Record 25 of Set 15 | nyaunglebin
# Processing Record 26 of Set 15 | nanning
# Processing Record 27 of Set 15 | rabaul
# Processing Record 28 of Set 15 | vila
# Processing Record 29 of Set 15 | arona
# Processing Record 30 of Set 15 | scottsburgh
# City not found. Skipping...
# Processing Record 31 of Set 15 | magomeni
# Processing Record 32 of Set 15 | tarata
# Processing Record 33 of Set 15 | dongning
# Processing Record 34 of Set 15 | boulsa
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# 683 city records were retrived

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Anadyr  64.7500  177.4833    -35.52        73          64        6.80
# 1    Mahebourg -20.4081   57.7000     76.24        79          12        1.59
# 2       Zatoka  46.0725   30.4654     37.94        71           0        4.03
# 3   Butaritari   3.0707  172.7902     81.46        78          79       15.26
# 4        Bluff -46.6000  168.3333     57.79        67          21       14.03
# 5    Saskylakh  71.9167  114.0833      2.57        92          93       12.62
# 6  Provideniya  64.3833 -173.3000    -16.13        91           8        9.40
# 7     Zhigansk  66.7697  123.3711    -30.05       100          92        5.46
# 8    Busselton -33.6500  115.3333     59.09        90          54        4.27
# 9         Asau  46.4333   26.4000     38.39        90          18        5.86
#
#   Country Current Description
# 0      RU       broken clouds
# 1      MU          few clouds
# 2      UA           clear sky
# 3      KI       broken clouds
# 4      NZ          few clouds
# 5      RU     overcast clouds
# 6      RU           clear sky
# 7      RU     overcast clouds
# 8      AU       broken clouds
# 9      RO          few clouds

# %%
#reorder he dataframe columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]

# %%
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Anadyr      RU  64.7500  177.4833    -35.52        73          64
# 1    Mahebourg      MU -20.4081   57.7000     76.24        79          12
# 2       Zatoka      UA  46.0725   30.4654     37.94        71           0
# 3   Butaritari      KI   3.0707  172.7902     81.46        78          79
# 4        Bluff      NZ -46.6000  168.3333     57.79        67          21
# 5    Saskylakh      RU  71.9167  114.0833      2.57        92          93
# 6  Provideniya      RU  64.3833 -173.3000    -16.13        91           8
# 7     Zhigansk      RU  66.7697  123.3711    -30.05       100          92
# 8    Busselton      AU -33.6500  115.3333     59.09        90          54
# 9         Asau      RO  46.4333   26.4000     38.39        90          18
#
#    Wind Speed Current Description
# 0        6.80       broken clouds
# 1        1.59          few clouds
# 2        4.03           clear sky
# 3       15.26       broken clouds
# 4       14.03          few clouds
# 5       12.62     overcast clouds
# 6        9.40           clear sky
# 7        5.46     overcast clouds
# 8        4.27       broken clouds
# 9        5.86          few clouds

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
